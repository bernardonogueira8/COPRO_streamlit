# %%
import pandas as pd
import pygwalker as pyg
arquivo = "raw.xlsx"
Apac_df =pd.read_excel(arquivo, sheet_name="Relação_APAC",header=12)
Apac_df = Apac_df[[
    'Município','Unidade','CNS Paciente','CPF Paciente', 'APAC','Tipo APAC','CNS Profissional','Competência Produção','Valor Glosa'
]]
Erros_df =pd.read_excel(arquivo, sheet_name="Erros Encontrados",header=12)
Erros_df = Erros_df[[
    'Município','Unidade','Competência Produção', 'APAC','CNS Paciente','CPF Paciente', 'Erro'
]]
